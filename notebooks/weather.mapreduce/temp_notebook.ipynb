# %%
import pandas as pd
import numpy as np
import sklearn as sk
print 'pandas version: ',pd.__version__
print 'numpy version:',np.__version__
print 'sklearn version:',sk.__version__
# Out:
# pandas version:  0.13.1
# numpy version: 1.8.1
# sklearn version: 0.14.1

# %%
import sys
home_dir='/home/ubuntu/UCSD_BigData'
sys.path.append(home_dir+'/utils')
from find_waiting_flow import *
from AWS_keypair_management import *

# %%
import pickle
Creds= pickle.load(open('/home/ubuntu/Vault/Creds.pkl','rb'))
print Creds.keys()
print Creds['mrjob'].keys()
pair=Creds['mrjob']
key_id=pair['key_id']
secret_key=pair['secret_key']
ID=pair['ID']
s3_log = pair['s3_logs']
print ID,key_id,secret_key
# Out:
# ['launcher', 'mrjob']
# ['key_id', 'secret_key', 's3_logs', 'ID', 's3_scratch']
# 666534009273 AKIAIG2KPQXQREBRHWWQ E9RCuBdMmWq7I17XR5hX3U4b4HRU17/9IlrUCOpc

# %%
local_data='../../data/weather/SAMPLE_TMAX.csv'
# !ls -l $local_data
# Out:
# -rw-rw-r-- 1 ubuntu ubuntu 26114979 May  7 19:47 ../../data/weather/SAMPLE_TMAX.csv

# %%
job_flow_id=find_waiting_flow(key_id,secret_key)
job_flow_id
# Out:
# <boto.emr.emrobject.JobFlow object at 0x2375410> no_script.yoavfreund.20140525.174308.746673 j-LTOJMJ14G840 WAITING
# <boto.emr.emrobject.JobFlow object at 0x58bdfd0> no_script.yoavfreund.20140526.014348.966938 j-6T8VIKMY8RHX WAITING
# <boto.emr.emrobject.JobFlow object at 0x58c2e50> no_script.yoavfreund.20140526.014403.503214 j-31UKS93V80CN7 WAITING
# u'j-31UKS93V80CN7'

# %%
# !python mr_weather_concatenate.py $local_data > temp_count1
# Out:
# using configs in /home/ubuntu/.mrjob.conf
# creating tmp directory /tmp/mr_weather_concatenate.ubuntu.20140526.050552.630942
# writing to /tmp/mr_weather_concatenate.ubuntu.20140526.050552.630942/step-0-mapper_part-00000
# Counters from step 1:
#   MrJob Counters:
#     combiner: 20000
#     mapper-all: 20000
# writing to /tmp/mr_weather_concatenate.ubuntu.20140526.050552.630942/step-0-mapper-sorted
# > sort /tmp/mr_weather_concatenate.ubuntu.20140526.050552.630942/step-0-mapper_part-00000
# writing to /tmp/mr_weather_concatenate.ubuntu.20140526.050552.630942/step-0-reducer_part-00000
# Counters from step 1:
#   MrJob Counters:
#     combiner: 20000
#     mapper-all: 20000
#     reducer: 20000
# Moving /tmp/mr_weather_concatenate.ubuntu.20140526.050552.630942/step-0-reducer_part-00000 -> /tmp/mr_weather_concatenate.ubuntu.20140526.050552.630942/output/part-00000
# Streaming final output from /tmp/mr_weather_concatenate.ubuntu.20140526.050552.630942/output
# removing tmp directory /tmp/mr_weather_concatenate.ubuntu.20140526.050552.630942

# %%
fin = file('temp_count1')
fout = open('temp_max_result','w')

while 1:
    temp_char = fin.read(1)
    if len(temp_char) == 0: # Zero length indicates EOF
        break
    if temp_char!=']' and temp_char!='[' and temp_char!=',' and temp_char!='"':
        if temp_char == '	':
            fout.write(' ')
        else:
            fout.write(temp_char)
fin.close()
fout.close()

# %%
# !head -1 temp_max_result
# Out:
# AG000060390 1977 201 188 200 125 144 174 128 135 122 174 172 117 147 207 169 132 144 162 134 155 174 177 172 153 200 238 233 230 159 209 154 165 156 183 192 212 180 184 191 202 219 187 166 148 155 152 165 182 170 194 226 222 172 258 160 178 196 224 202 187 190 235 262 237 245 240 188 196 198 232 184 197 214 202 260 240 198 197 211 212 195 194 189 203 212 208 208 117 92 126 163 227 243 241 253 215 220 189 132 172 157 170 217 216 205 196 164 210 161 169 184 216 265 254 245 262 298 251 250 230 200 236 176 189 208 220 218 212 207 227 278 301 250 253 254 215 165 212 219 250 252 230 240 240 240 240 233 232 218 245 202 223 219 233 239 260 253 300 354 286 300 266 375 241 243 270 262 286 292 280 284 260 249 246 253 264 330 286 295 267 250 256 245 263 244 270 316 301 280 280 276 273 283 294 319 297 278 273 296 308
# 36 -128 -131 -140 -110 -104  -87  -60 ...
# 37    0    0    0    0    0    0    0 ...
# 38  -22   59   60   87  124   94   88 ...
# 39   10   25   31   50   38   40   53 ...
# 40  -30   26   23   17    1    5  -21 ...
# 41  -15  -26  -10  -58    2   35   55 ...
# 42  -26  -22  -43  -49  -53  -33   20 ...
# 43    0    0    0    0    0    0    0 ...
# 44    0    0    0    0    0    0    0 ...
# 45    0    0  100    0  128    0    0 ...
# 46    0    0    0    0    0    0    0 ...
# 47    0    0    0    0    0    0    0 ...
# 48    0    0    0    0    0    0    0 ...
# 49    0    0    0    0    0    0    0 ...
# 50  404  247  337  320  345  335  355 ...
# 51  343  376  383  384  424  435  384 ...
# 52  332  319  353  375  381  396  393 ...
# 53  383  424  427  411  420  350  281 ...
# 54  372  330  364  326  320  352  377 ...
# 55  380    0    0  386    0    0  378 ...
# 56    0    0  365  367    0    0    0 ...
# 57    0    0    0    0  389  355    0 ...
# 58  346  302  323  351  349  311  307 ...
# 59  320  330  336  348  369  290  290 ...
#     ...  ...  ...  ...  ...  ...  ...
#
# [20000 rows x 367 columns]

# %%
size(data2,0)
# Out:
# 124

# %%
import pandas as pd
colspecs = [(0, 11), (11, 21), (21, 31), (31, 38),(39,41),(41,72),(72,76),(76,80),(80,86)]
stations = pd.read_fwf('ghcnd-stations_buffered.txt', colspecs=colspecs, header=None, index_col=0,
                       names=['latitude','longitude','elevation','state','name','GSNFLAG','HCNFLAG','WMOID'])
 
Data = pd.read_csv('counts', header=None,names=['station','count','area','latitude1','latitude2','longitude1','longitude2'],delim_whitespace=True)
Data['latitude1']=-90
Data['latitude2']=91
Data['longitude1']=-180
Data['longitude2']=181
Data.head()
 
djoin=Data.join(stations,on='station')
 
def mypartition(start,end,index,l):
    print 'aaa'
    if end-start<=1:
        print 'bottom'
        return l
    if index=='latitude':
        index2='longitude'
    else:
        index2='latitude'
    a=djoin[start:end].sort(index,inplace=False)
    djoin[start:end]=a
    temp=sum(djoin[start:end]['count'])
    print temp
    if temp<50000 :
        print 'bottom'
        return l
    num=0
    for i in range(start,end):
        #print num
        num=num+djoin.ix[i,['count']].values
        if num>temp/2:
            print 'ok'
            if start==i:
                djoin.ix[start:i+1,['area']]=l
                t1=(djoin.ix[i,[index]].values+djoin.ix[i+1,[index]].values)/2
                print t1
                djoin.ix[start:i+1,[index+'2']]=t1
                l=l+1
                l=mypartition(start,i+1,index2,l)
                djoin.ix[i+1:end,['area']]=l
                djoin.ix[i+1:end,[index+'1']]=t1
                l=l+1
                l=mypartition(i+1,end,index2,l)
                return l
            else:
                djoin.ix[start:i,['area']]=l
                t1=(djoin.ix[i,[index]].values+djoin.ix[i-1,[index]].values)/2
                print t1
                djoin.ix[start:i,[index+'2']]=t1
                l=l+1
                l=mypartition(start,i,index2,l)
                djoin.ix[i:end,['area']]=l
                djoin.ix[i:end,[index+'1']]=t1
                l=l+1
                l=mypartition(i,end,index2,l)
                return l
 
mypartition(0,len(djoin.index),'latitude',0)

# %%
a = [[1,1],[1,1]]
np.matrix(a)
# Out:
# matrix([[1, 1],
#         [1, 1]])

# %%
a=[1,1]
b=[2,2]
c = add(a,b)
d = add(c,a)

# %%
d
# Out:
# array([4, 4])

# %%
a = 'aaa,ddd'

# %%
a[4]
# Out:
# 'd'

# %%
A=[12,3,4]
sort(A)
# Out:
# array([ 3,  4, 12])
